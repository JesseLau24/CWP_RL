# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split

# Load the training, validation, and test data
train_df = pd.read_csv('Training/train_2013_2020.csv', parse_dates=["Date"])
valid_df = pd.read_csv('Training/valid_2021_2022.csv', parse_dates=["Date"])
test_df = pd.read_csv('Training/test_2023_2025.csv', parse_dates=["Date"])

print("\nDataframe loaded!")
# Out:
# 2025-04-07 15:32:58.855917: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-07 15:32:58.887117: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-07 15:32:59.560222: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Dataframe loaded!

# %%
# Take a look:
train_df.head()
# Out:
#         Date Ticker       Open       High        Low      Close     Volume  \
# 0 2013-10-16   AAPL  15.495887  15.549728  15.447617  15.505789  251101200
# 1 2013-10-16    AMD   4.100000   4.100000   4.030000   4.090000   34138300
# 2 2013-10-16   AMZN  15.419000  15.540000  15.277500  15.524500   43414000
# 3 2013-10-16    CRM  50.696837  52.636007  50.696837  52.287952    5546400
# 4 2013-10-16  GOOGL  22.063435  22.373763  22.017109  22.366291   80223696
#
#       SMA_50    SMA_200     EMA_12     EMA_26     RSI_14      MACD  \
# 0  15.032551  13.979203  15.189830  15.045010  62.303597  0.144821
# 1   3.723600   3.341950   3.897477   3.840017  61.363635  0.057461
# 2  15.018840  13.954720  15.468081  15.382953  44.246720  0.085127
# 3  48.406231  43.628603  51.223758  50.579232  46.932021  0.644525
# 4  21.837339  20.964062  21.855881  21.870292  60.675127 -0.014411
#
#    Bollinger_Upper  Bollinger_Lower           OBV    VIX         GSPC  \
# 0        15.554754        14.534793 -2.499042e+09  14.71  1721.540039
# 1         4.066061         3.667939  5.815740e+08  14.71  1721.540039
# 2        16.190246        15.028954  5.679480e+08  14.71  1721.540039
# 3        53.720300        49.767677  1.610380e+07  14.71  1721.540039
# 4        22.534776        21.243958  7.742250e+08  14.71  1721.540039
#
#    5_day_return
# 0      4.759481
# 1    -23.227384
# 2      5.240101
# 3      1.445403
# 4     14.852515

# %%
# Take a look:
valid_df.head()
# Out:
#         Date Ticker        Open        High         Low       Close  \
# 0 2021-01-04   ORCL   60.790056   60.799448   59.361688   59.906723
# 1 2021-01-04   AAPL  130.419822  130.507728  123.816779  126.405251
# 2 2021-01-04    AMD   92.110001   96.059998   90.919998   92.300003
# 3 2021-01-04   AMZN  163.500000  163.600006  157.201004  159.331497
# 4 2021-01-04    CRM  221.403348  222.507183  214.521787  219.086288
#
#       Volume      SMA_50     SMA_200      EMA_12      EMA_26     RSI_14  \
# 0   11249900   55.822542   52.522186   59.991729   58.496417  69.674248
# 1  143301900  118.424647   98.343024  127.618833  124.236822  62.119154
# 2   51802600   87.175000   70.334900   92.376486   91.330042  52.120032
# 3   88228000  158.657401  144.192485  161.298667  160.159392  57.205009
# 4   10319900  237.030087  206.766522  223.160623  227.773140  45.993135
#
#        MACD  Bollinger_Upper  Bollinger_Lower           OBV        VIX  \
# 0  1.495312        63.279143        54.630446  1.262044e+09  26.969999
# 1  3.382012       134.230001       115.929484  5.634157e+09  26.969999
# 2  1.046445        97.483014        88.911988  5.505119e+09  26.969999
# 3  1.139274       165.847456       153.786495  1.081132e+10  26.969999
# 4 -4.612517       229.233860       217.163813  4.549484e+08  26.969999
#
#           GSPC  5_day_return
# 0  3700.649902     -0.751080
# 1  3700.649902     -0.332287
# 2  3700.649902      5.362943
# 3  3700.649902     -2.272622
# 4  3700.649902     -0.935030

# %%
# Take a look:
test_df.head()
# Out:
#         Date Ticker        Open        High         Low       Close  \
# 0 2023-01-03   NVDA   14.838840   14.983722   14.084458   14.303279
# 1 2023-01-03   MSFT  238.676603  241.298234  233.099488  235.240005
# 2 2023-01-03   META  122.243862  125.777212  121.706394  124.154854
# 3 2023-01-03   INTC   26.083715   26.103001   25.428008   25.775146
# 4 2023-01-03   ORCL   80.057697   81.387619   79.853840   81.271133
#
#       Volume      SMA_50     SMA_200      EMA_12      EMA_26     RSI_14  \
# 0  401277000   15.347197   16.943800   15.178464   15.547839  24.371205
# 1   25740000  236.342352  254.952796  236.743146  238.152699  35.422830
# 2   35528500  112.542985  159.545859  118.442426  117.021508  62.252629
# 3   31308000   27.102699   33.790724   25.705760   26.343984  31.985293
# 4    8997500   76.876740   72.006401   78.977334   78.157864  60.445261
#
#        MACD  Bollinger_Upper  Bollinger_Lower           OBV   VIX  \
# 0 -0.369375        18.489713        13.560524  7.974911e+10  22.9
# 1 -1.409553       252.360838       227.619924  3.482504e+09  22.9
# 2  1.420918       123.416193       111.284665  4.040500e+09  22.9
# 3 -0.638224        28.519716        24.081638  6.730069e+08  22.9
# 4  0.819470        80.486745        76.076666  1.367710e+09  22.9
#
#           GSPC  5_day_return
# 0  3824.139893     11.135182
# 1  3824.139893     -4.478672
# 2  3824.139893      6.613754
# 3  3824.139893     10.138409
# 4  3824.139893      3.708001

# %%
# Sort by Date to ensure correct ordering (important for time series)
train_df.sort_values(by=["Date", "Ticker"], inplace=True)
valid_df.sort_values(by=["Date", "Ticker"], inplace=True)
test_df.sort_values(by=["Date", "Ticker"], inplace=True)

# Encode Ticker column (if you want to keep it as a feature)
label_encoder = LabelEncoder()
train_df['Ticker'] = label_encoder.fit_transform(train_df['Ticker'])
valid_df['Ticker'] = label_encoder.transform(valid_df['Ticker'])  # Use same encoding for validation
test_df['Ticker'] = label_encoder.transform(test_df['Ticker'])  # Use same encoding for test

# Separate the target column and features for scaling
train_features = train_df.drop(columns=['Date', '5_day_return'])
valid_features = valid_df.drop(columns=['Date', '5_day_return'])
test_features = test_df.drop(columns=['Date', '5_day_return'])
y_train = train_df['5_day_return'].values
y_val = valid_df['5_day_return'].values
y_test = test_df['5_day_return'].values

# Normalize the features (MinMax scaling to [0, 1])
scaler = MinMaxScaler(feature_range=(0, 1))

# Fit the scaler on training features and apply to all sets
train_scaled_features = scaler.fit_transform(train_features)
valid_scaled_features = scaler.transform(valid_features)
test_scaled_features = scaler.transform(test_features)

# Create sequences for LSTM (60 days window) for each dataset
def create_sequences(data, window_size=60):
    X, y = [], []
    for i in range(window_size, len(data)):
        X.append(data[i-window_size:i])  # Input: previous 60 days
        y.append(data[i, -1])  # Output: 5-day return (last column)
    return np.array(X), np.array(y)

# Apply function to create sequences for each dataset
X_train, y_train = create_sequences(train_scaled_features)
X_val, y_val = create_sequences(valid_scaled_features)
X_test, y_test = create_sequences(test_scaled_features)

# Print the shapes of the resulting datasets
print(f"Training data shape: {X_train.shape}")
print(f"Validation data shape: {X_val.shape}")
print(f"Testing data shape: {X_test.shape}")
# Out:
# Training data shape: (18100, 60, 17)
# Validation data shape: (4970, 60, 17)
# Testing data shape: (5550, 60, 17)

# %%
# Build the LSTM model
model = tf.keras.Sequential()

# Add LSTM layers
model.add(tf.keras.layers.LSTM(units=64, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(tf.keras.layers.LSTM(units=32))
model.add(tf.keras.layers.Dense(16, activation='relu'))  # Fully connected layer
model.add(tf.keras.layers.Dense(1))  # Output layer (predicts the 5-day return)

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Summary of the model
model.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1744029180.319672   77347 gpu_device.cc:2340] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# /home/jesse/Projects/myenvs/tf_nightly/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 60, 64)         │        20,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 33,953 (132.63 KB)
#  Trainable params: 33,953 (132.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=200, batch_size=32, validation_data=(X_val, y_val), verbose=1)

# Plot the training and validation loss (optional)
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - loss: 0.0147 - val_loss: 0.0187
# Epoch 2/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.8040e-04 - val_loss: 0.0067
# Epoch 3/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.5240e-04 - val_loss: 0.0062
# Epoch 4/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.3924e-04 - val_loss: 0.0034
# Epoch 5/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.0598e-04 - val_loss: 0.0034
# Epoch 6/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.0798e-04 - val_loss: 0.0034
# Epoch 7/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 8.6848e-05 - val_loss: 0.0025
# Epoch 8/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 8.2799e-05 - val_loss: 6.8856e-04
# Epoch 9/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 8.3365e-05 - val_loss: 0.0029
# Epoch 10/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 8.3113e-05 - val_loss: 8.1435e-04
# Epoch 11/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 6.6139e-05 - val_loss: 0.0016
# Epoch 12/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 5.7354e-05 - val_loss: 0.0011
# Epoch 13/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 6.1921e-05 - val_loss: 0.0011
# Epoch 14/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 5.5306e-05 - val_loss: 1.3916e-04
# Epoch 15/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 4.5750e-05 - val_loss: 1.6235e-04
# Epoch 16/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 5.8448e-05 - val_loss: 2.4647e-04
# Epoch 17/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 4.7961e-05 - val_loss: 3.7777e-04
# Epoch 18/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 4.6983e-05 - val_loss: 0.0014
# Epoch 19/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.6821e-05 - val_loss: 4.8915e-04
# Epoch 20/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.8798e-05 - val_loss: 8.0286e-04
# Epoch 21/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.7036e-05 - val_loss: 4.7212e-04
# Epoch 22/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 4.0714e-05 - val_loss: 3.1867e-04
# Epoch 23/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.1456e-05 - val_loss: 4.8864e-04
# Epoch 24/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.6175e-05 - val_loss: 4.2970e-04
# Epoch 25/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.9618e-05 - val_loss: 6.6213e-04
# Epoch 26/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.4434e-05 - val_loss: 9.8942e-04
# Epoch 27/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.7615e-05 - val_loss: 3.2740e-04
# Epoch 28/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.5948e-05 - val_loss: 6.0299e-04
# Epoch 29/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.1793e-05 - val_loss: 1.4922e-04
# Epoch 30/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.8981e-05 - val_loss: 3.8348e-04
# Epoch 31/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.5933e-05 - val_loss: 2.6296e-04
# Epoch 32/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.1064e-05 - val_loss: 1.7956e-04
# Epoch 33/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 3.7754e-05 - val_loss: 8.0842e-04
# Epoch 34/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 3.5057e-05 - val_loss: 0.0010
# Epoch 35/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.5017e-05 - val_loss: 8.6661e-04
# Epoch 36/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.7799e-05 - val_loss: 4.7044e-04
# Epoch 37/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.7019e-05 - val_loss: 5.9507e-04
# Epoch 38/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 4.1641e-05 - val_loss: 1.4111e-04
# Epoch 39/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.3201e-05 - val_loss: 1.4027e-04
# Epoch 40/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 2.9496e-05 - val_loss: 3.1697e-04
# Epoch 41/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.7820e-05 - val_loss: 3.1524e-04
# Epoch 42/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.8453e-05 - val_loss: 4.8812e-04
# Epoch 43/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.7499e-05 - val_loss: 1.3845e-04
# Epoch 44/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.0927e-05 - val_loss: 1.4281e-04
# Epoch 45/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.4957e-05 - val_loss: 1.3372e-04
# Epoch 46/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.4544e-05 - val_loss: 2.1400e-04
# Epoch 47/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.6565e-05 - val_loss: 6.1724e-04
# Epoch 48/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.0983e-05 - val_loss: 1.9696e-04
# Epoch 49/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.5000e-05 - val_loss: 3.9836e-04
# Epoch 50/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.7295e-05 - val_loss: 1.9140e-04
# Epoch 51/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.8505e-05 - val_loss: 5.9674e-04
# Epoch 52/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.5384e-05 - val_loss: 6.2186e-04
# Epoch 53/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.5202e-05 - val_loss: 2.7274e-04
# Epoch 54/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.8453e-05 - val_loss: 3.1660e-04
# Epoch 55/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 2.6927e-05 - val_loss: 5.0962e-04
# Epoch 56/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 2.4887e-05 - val_loss: 4.3399e-04
# Epoch 57/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.6235e-05 - val_loss: 2.2707e-04
# Epoch 58/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.3683e-05 - val_loss: 0.0012
# Epoch 59/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 4.1176e-05 - val_loss: 2.3183e-04
# Epoch 60/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.4178e-05 - val_loss: 4.8248e-04
# Epoch 61/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.5491e-05 - val_loss: 1.8498e-04
# Epoch 62/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.0572e-05 - val_loss: 4.4741e-04
# Epoch 63/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.7766e-05 - val_loss: 4.4297e-04
# Epoch 64/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.0294e-05 - val_loss: 1.6952e-04
# Epoch 65/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.2749e-05 - val_loss: 2.2981e-04
# Epoch 66/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.5800e-05 - val_loss: 5.5465e-04
# Epoch 67/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.8908e-05 - val_loss: 2.2209e-04
# Epoch 68/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.4541e-05 - val_loss: 2.1539e-04
# Epoch 69/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.7627e-05 - val_loss: 4.5605e-04
# Epoch 70/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.0267e-05 - val_loss: 2.2955e-04
# Epoch 71/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 4.2178e-05 - val_loss: 9.2570e-04
# Epoch 72/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.5308e-05 - val_loss: 4.1340e-04
# Epoch 73/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.4765e-05 - val_loss: 3.6130e-04
# Epoch 74/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.1289e-05 - val_loss: 5.9768e-04
# Epoch 75/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.0995e-05 - val_loss: 3.8340e-04
# Epoch 76/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.9179e-05 - val_loss: 2.0076e-04
# Epoch 77/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.1456e-05 - val_loss: 9.0996e-04
# Epoch 78/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 3.9563e-05 - val_loss: 5.3597e-04
# Epoch 79/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.8739e-05 - val_loss: 3.2072e-04
# Epoch 80/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.5882e-05 - val_loss: 4.0909e-04
# Epoch 81/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.5330e-05 - val_loss: 1.8574e-04
# Epoch 82/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.6272e-05 - val_loss: 3.4352e-04
# Epoch 83/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.7931e-05 - val_loss: 4.9921e-04
# Epoch 84/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.7449e-05 - val_loss: 2.9065e-04
# Epoch 85/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.5225e-05 - val_loss: 5.2206e-04
# Epoch 86/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.3741e-05 - val_loss: 8.0345e-04
# Epoch 87/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.7361e-05 - val_loss: 8.0936e-04
# Epoch 88/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.1335e-05 - val_loss: 6.0236e-04
# Epoch 89/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.2903e-05 - val_loss: 3.8307e-04
# Epoch 90/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.9203e-05 - val_loss: 7.4910e-04
# Epoch 91/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.6561e-05 - val_loss: 3.7231e-04
# Epoch 92/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.5543e-05 - val_loss: 5.9356e-04
# Epoch 93/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.8726e-05 - val_loss: 6.9033e-04
# Epoch 94/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 2.6147e-05 - val_loss: 4.8368e-04
# Epoch 95/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 2.4093e-05 - val_loss: 6.5829e-04
# Epoch 96/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.3174e-05 - val_loss: 4.7623e-04
# Epoch 97/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.6631e-05 - val_loss: 0.0011
# Epoch 98/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.8646e-05 - val_loss: 4.6350e-04
# Epoch 99/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.4788e-05 - val_loss: 4.3475e-04
# Epoch 100/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.4053e-05 - val_loss: 4.4351e-04
# Epoch 101/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.4943e-05 - val_loss: 4.4214e-04
# Epoch 102/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.3996e-05 - val_loss: 5.4868e-04
# Epoch 103/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.1738e-05 - val_loss: 3.4312e-04
# Epoch 104/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.0509e-05 - val_loss: 4.2192e-04
# Epoch 105/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.4067e-05 - val_loss: 6.8849e-04
# Epoch 106/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.7714e-05 - val_loss: 7.7140e-04
# Epoch 107/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.6369e-05 - val_loss: 4.8102e-04
# Epoch 108/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.0904e-05 - val_loss: 3.7139e-04
# Epoch 109/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.4868e-05 - val_loss: 3.8395e-04
# Epoch 110/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.3129e-05 - val_loss: 2.6121e-04
# Epoch 111/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 2.4829e-05 - val_loss: 9.6379e-04
# Epoch 112/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.8156e-05 - val_loss: 3.5559e-04
# Epoch 113/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.2291e-05 - val_loss: 3.8275e-04
# Epoch 114/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.9767e-05 - val_loss: 8.6874e-04
# Epoch 115/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.5648e-05 - val_loss: 9.1261e-04
# Epoch 116/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.0889e-05 - val_loss: 6.5795e-04
# Epoch 117/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.4839e-05 - val_loss: 7.0283e-04
# Epoch 118/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.1082e-05 - val_loss: 5.2901e-04
# Epoch 119/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.5369e-05 - val_loss: 6.7429e-04
# Epoch 120/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.3751e-05 - val_loss: 7.9854e-04
# Epoch 121/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.2490e-05 - val_loss: 5.8047e-04
# Epoch 122/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.5193e-05 - val_loss: 4.5004e-04
# Epoch 123/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.0755e-05 - val_loss: 6.3196e-04
# Epoch 124/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.6430e-05 - val_loss: 2.4792e-04
# Epoch 125/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.1433e-05 - val_loss: 3.0335e-04
# Epoch 126/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 2.3254e-05 - val_loss: 8.2170e-04
# Epoch 127/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.1288e-05 - val_loss: 7.2783e-04
# Epoch 128/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.1991e-05 - val_loss: 4.0467e-04
# Epoch 129/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.1568e-05 - val_loss: 0.0011
# Epoch 130/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.3284e-05 - val_loss: 2.4334e-04
# Epoch 131/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.3733e-05 - val_loss: 5.9011e-04
# Epoch 132/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 2.4332e-05 - val_loss: 5.8801e-04
# Epoch 133/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 2.1069e-05 - val_loss: 7.2074e-04
# Epoch 134/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.8816e-05 - val_loss: 4.8831e-04
# Epoch 135/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.1793e-05 - val_loss: 5.1792e-04
# Epoch 136/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.4658e-05 - val_loss: 3.4453e-04
# Epoch 137/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.4576e-05 - val_loss: 3.6276e-04
# Epoch 138/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.6332e-05 - val_loss: 5.1097e-04
# Epoch 139/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.2924e-05 - val_loss: 3.8929e-04
# Epoch 140/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.7981e-05 - val_loss: 4.8938e-04
# Epoch 141/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.1669e-05 - val_loss: 7.1600e-04
# Epoch 142/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.3025e-05 - val_loss: 2.5022e-04
# Epoch 143/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 2.3062e-05 - val_loss: 5.5034e-04
# Epoch 144/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 4.1818e-05 - val_loss: 0.0013
# Epoch 145/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.2597e-05 - val_loss: 0.0010
# Epoch 146/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.8139e-05 - val_loss: 0.0011
# Epoch 147/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.7412e-05 - val_loss: 6.6374e-04
# Epoch 148/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.7850e-05 - val_loss: 3.1688e-04
# Epoch 149/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.1912e-05 - val_loss: 9.1916e-04
# Epoch 150/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.3305e-05 - val_loss: 0.0015
# Epoch 151/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.6507e-05 - val_loss: 7.0207e-04
# Epoch 152/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 3.0799e-05 - val_loss: 3.4704e-04
# Epoch 153/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.4956e-05 - val_loss: 3.2059e-04
# Epoch 154/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.5066e-05 - val_loss: 4.7531e-04
# Epoch 155/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.2994e-05 - val_loss: 4.0107e-04
# Epoch 156/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 2.1134e-05 - val_loss: 9.2071e-04
# Epoch 157/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.6353e-05 - val_loss: 8.6217e-04
# Epoch 158/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.2131e-05 - val_loss: 3.8936e-04
# Epoch 159/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 2.2632e-05 - val_loss: 4.9493e-04
# Epoch 160/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.2569e-05 - val_loss: 8.1625e-04
# Epoch 161/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 2.6622e-05 - val_loss: 6.3810e-04
# Epoch 162/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.1037e-05 - val_loss: 8.1716e-04
# Epoch 163/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.2427e-05 - val_loss: 4.6428e-04
# Epoch 164/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.4791e-05 - val_loss: 7.7823e-04
# Epoch 165/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 2.0864e-05 - val_loss: 6.6314e-04
# Epoch 166/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.0186e-05 - val_loss: 6.7146e-04
# Epoch 167/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.4651e-05 - val_loss: 6.0158e-04
# Epoch 168/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 2.0070e-05 - val_loss: 4.4858e-04
# Epoch 169/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.7925e-05 - val_loss: 9.9803e-04
# Epoch 170/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.9507e-05 - val_loss: 9.1503e-04
# Epoch 171/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 1.8549e-05 - val_loss: 7.0691e-04
# Epoch 172/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.0636e-05 - val_loss: 3.0510e-04
# Epoch 173/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 2.0966e-05 - val_loss: 6.6545e-04
# Epoch 174/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.8417e-05 - val_loss: 2.8218e-04
# Epoch 175/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 3.5733e-05 - val_loss: 2.8015e-04
# Epoch 176/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.9731e-05 - val_loss: 2.6916e-04
# Epoch 177/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.0583e-05 - val_loss: 0.0018
# Epoch 178/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 1.9162e-05 - val_loss: 5.7833e-04
# Epoch 179/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.4424e-05 - val_loss: 5.6224e-04
# Epoch 180/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.1582e-05 - val_loss: 7.9615e-04
# Epoch 181/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.0835e-05 - val_loss: 6.5450e-04
# Epoch 182/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 1.9699e-05 - val_loss: 8.7185e-04
# Epoch 183/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.8101e-05 - val_loss: 7.4372e-04
# Epoch 184/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.1515e-05 - val_loss: 0.0014
# Epoch 185/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 1.9753e-05 - val_loss: 9.1409e-04
# Epoch 186/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.2300e-05 - val_loss: 9.5354e-04
# Epoch 187/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.2220e-05 - val_loss: 6.0870e-04
# Epoch 188/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.1754e-05 - val_loss: 6.5667e-04
# Epoch 189/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.7680e-05 - val_loss: 4.7040e-04
# Epoch 190/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 1.8798e-05 - val_loss: 3.0525e-04
# Epoch 191/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.3032e-05 - val_loss: 6.3351e-04
# Epoch 192/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.9107e-05 - val_loss: 6.5008e-04
# Epoch 193/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.9863e-05 - val_loss: 6.6601e-04
# Epoch 194/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 1.8671e-05 - val_loss: 6.2423e-04
# Epoch 195/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.9818e-05 - val_loss: 9.0404e-04
# Epoch 196/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 1.7754e-05 - val_loss: 0.0021
# Epoch 197/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.4047e-05 - val_loss: 6.4608e-04
# Epoch 198/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - loss: 2.0543e-05 - val_loss: 3.7289e-04
# Epoch 199/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 1.9690e-05 - val_loss: 4.7285e-04
# Epoch 200/200
# 566/566 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - loss: 2.0313e-05 - val_loss: 4.7864e-04

# %%
# Evaluate the model on the test data
test_loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")
# Out:
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0072
# Test Loss: 0.032598190009593964

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Predict the test data
y_pred = model.predict(X_test)

# Evaluate the MAE, MSE, and R-squared
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared: {r2}")
# Out:
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Mean Absolute Error (MAE): 0.12940262935382113
# Mean Squared Error (MSE): 0.032598191832274
# R-squared: 0.7157146921623827

# %%
import matplotlib.pyplot as plt

# Plot predicted vs true values
plt.figure(figsize=(10,6))
plt.plot(y_test[:2000], label="True 5-day Return", color='blue')
plt.plot(y_pred[:2000], label="Predicted 5-day Return", color='red')
plt.title("Predicted vs True 5-day Return")
plt.xlabel("Time Steps")
plt.ylabel("5-day Return")
plt.legend()
plt.show()

# %%
print(f"Shape of y_pred: {y_pred.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of y_pred: (5550, 1)
# Shape of y_test: (5550,)

# %%
# Flatten y_pred to a 1D array
y_pred = y_pred.squeeze()

# Now both y_pred and y_test will be 1D arrays and have the same shape
print(f"Shape of y_pred: {y_pred.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of y_pred: (5550,)
# Shape of y_test: (5550,)

# %%
# Plot residuals
residuals = y_test - y_pred
plt.figure(figsize=(10,10))
plt.scatter(range(len(residuals)), residuals, color='purple')
plt.axhline(0, color='black', linestyle='--')
plt.title("Residual Plot")
plt.show()
