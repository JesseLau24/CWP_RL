# %%
import numpy as np
import pandas as pd
import torch
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

# Load the training, validation, and test data
train_df = pd.read_csv('Training/train_2013_2020.csv', parse_dates=["Date"])
valid_df = pd.read_csv('Training/valid_2021_2022.csv', parse_dates=["Date"])
test_df = pd.read_csv('Training/test_2023_2025.csv', parse_dates=["Date"])

print("\nDataframe loaded!")
# Out:
# Dataframe loaded!

# %%
# Sort by Date to ensure correct ordering
train_df.sort_values(by=["Date", "Ticker"], inplace=True)
valid_df.sort_values(by=["Date", "Ticker"], inplace=True)
test_df.sort_values(by=["Date", "Ticker"], inplace=True)

# Encode Ticker
label_encoder = LabelEncoder()
train_df['Ticker'] = label_encoder.fit_transform(train_df['Ticker'])
valid_df['Ticker'] = label_encoder.transform(valid_df['Ticker'])
test_df['Ticker'] = label_encoder.transform(test_df['Ticker'])

# Separate features and targets
train_features = train_df.drop(columns=['Date', '5_day_return'])
valid_features = valid_df.drop(columns=['Date', '5_day_return'])
test_features = test_df.drop(columns=['Date', '5_day_return'])
y_train = train_df['5_day_return'].values
y_val = valid_df['5_day_return'].values
y_test = test_df['5_day_return'].values

# Normalize features
scaler = MinMaxScaler()
train_scaled_features = scaler.fit_transform(train_features)
valid_scaled_features = scaler.transform(valid_features)
test_scaled_features = scaler.transform(test_features)

# Sequence generator
def create_sequences(features, targets, window_size=60):
    X, y = [], []
    for i in range(window_size, len(features)):
        X.append(features[i - window_size:i])
        y.append(targets[i])
    return np.array(X), np.array(y)

# Create LSTM-ready sequences
X_train, y_train = create_sequences(train_scaled_features, y_train)
X_val, y_val = create_sequences(valid_scaled_features, y_val)
X_test, y_test = create_sequences(test_scaled_features, y_test)

# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32).unsqueeze(1)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1)

print(f"✅ Training shape: {X_train_tensor.shape}")
print(f"✅ Validation shape: {X_val_tensor.shape}")
print(f"✅ Test shape: {X_test_tensor.shape}")
# Out:
# ✅ Training shape: torch.Size([18100, 60, 17])
# ✅ Validation shape: torch.Size([4970, 60, 17])
# ✅ Test shape: torch.Size([5550, 60, 17])

# %%
import torch
import torch.nn as nn

class StockLSTM(nn.Module):
    def __init__(self, input_size):
        super(StockLSTM, self).__init__()
        
        self.lstm1 = nn.LSTM(input_size=input_size, hidden_size=64, batch_first=True, dropout=0.0, num_layers=1)
        self.lstm2 = nn.LSTM(input_size=64, hidden_size=32, batch_first=True, dropout=0.0, num_layers=1)
        
        self.fc1 = nn.Linear(32, 16)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(16, 1)

    def forward(self, x):
        out, _ = self.lstm1(x)
        out, _ = self.lstm2(out)
        out = out[:, -1, :]  # Get the output of the last time step
        out = self.fc1(out)
        out = self.relu(out)
        out = self.fc2(out)
        return out

# %%
input_size = X_train_tensor.shape[2]  # Number of features per time step
model = StockLSTM(input_size)
print(model)
# Out:
# StockLSTM(
#   (lstm1): LSTM(17, 64, batch_first=True)
#   (lstm2): LSTM(64, 32, batch_first=True)
#   (fc1): Linear(in_features=32, out_features=16, bias=True)
#   (relu): ReLU()
#   (fc2): Linear(in_features=16, out_features=1, bias=True)
# )

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt

# Convert NumPy arrays to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.float32).unsqueeze(1)

# Create Datasets and DataLoaders
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
val_dataset = TensorDataset(X_val_tensor, y_val_tensor)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Check device type
print(f"Training on device: {device}")

# Loss and optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Training loop
num_epochs = 5000
train_losses = []
val_losses = []

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for X_batch, y_batch in train_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)

        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        running_loss += loss.detach().item()  # detach the tensor before using item()

    avg_train_loss = running_loss / len(train_loader)
    train_losses.append(avg_train_loss)

    # Validation loss
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            val_loss += loss.detach().item()  # detach the tensor before using item()

    avg_val_loss = val_loss / len(val_loader)
    val_losses.append(avg_val_loss)

    if (epoch + 1) % 10 == 0 or epoch == 0:
        print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}")
# Out:
# Training on device: cuda
# Epoch [1/5000], Train Loss: 21.8104, Val Loss: 31.1542
# Epoch [10/5000], Train Loss: 21.4642, Val Loss: 30.8219
# Epoch [20/5000], Train Loss: 20.9153, Val Loss: 30.5240
# Epoch [30/5000], Train Loss: 19.2364, Val Loss: 30.7418
# Epoch [40/5000], Train Loss: 16.4984, Val Loss: 33.8592
# Epoch [50/5000], Train Loss: 14.0901, Val Loss: 32.7756
# Epoch [60/5000], Train Loss: 12.1008, Val Loss: 33.3845
# Epoch [70/5000], Train Loss: 10.1211, Val Loss: 36.5310
# Epoch [80/5000], Train Loss: 8.5299, Val Loss: 36.7156
# Epoch [90/5000], Train Loss: 7.2117, Val Loss: 35.5492
# Epoch [100/5000], Train Loss: 6.1276, Val Loss: 35.6243
# Epoch [110/5000], Train Loss: 5.3893, Val Loss: 35.7544
# Epoch [120/5000], Train Loss: 5.1261, Val Loss: 37.9126
# Epoch [130/5000], Train Loss: 4.0126, Val Loss: 37.1121
# Epoch [140/5000], Train Loss: 3.4282, Val Loss: 38.9816
# Epoch [150/5000], Train Loss: 3.9039, Val Loss: 38.4968
# Epoch [160/5000], Train Loss: 3.0704, Val Loss: 38.3882
# Epoch [170/5000], Train Loss: 2.5537, Val Loss: 39.2449
# Epoch [180/5000], Train Loss: 2.3387, Val Loss: 38.6458
# Epoch [190/5000], Train Loss: 2.0149, Val Loss: 40.2611
# Epoch [200/5000], Train Loss: 2.2457, Val Loss: 40.0004
# Epoch [210/5000], Train Loss: 1.8658, Val Loss: 40.1991
# Epoch [220/5000], Train Loss: 1.9601, Val Loss: 39.6605
# Epoch [230/5000], Train Loss: 1.3636, Val Loss: 40.7166
# Epoch [240/5000], Train Loss: 1.5400, Val Loss: 40.7640
# Epoch [250/5000], Train Loss: 1.4141, Val Loss: 40.7422
# Epoch [260/5000], Train Loss: 1.4805, Val Loss: 41.4428
# Epoch [270/5000], Train Loss: 1.0521, Val Loss: 40.9929
# Epoch [280/5000], Train Loss: 1.3884, Val Loss: 42.1952
# Epoch [290/5000], Train Loss: 0.9046, Val Loss: 42.4343
# Epoch [300/5000], Train Loss: 1.0037, Val Loss: 41.1633
# Epoch [310/5000], Train Loss: 1.0218, Val Loss: 42.8736
# Epoch [320/5000], Train Loss: 0.8854, Val Loss: 42.5364
# Epoch [330/5000], Train Loss: 0.7941, Val Loss: 43.8671
# Epoch [340/5000], Train Loss: 0.6445, Val Loss: 42.8328
# Epoch [350/5000], Train Loss: 0.6276, Val Loss: 42.9443
# Epoch [360/5000], Train Loss: 0.8669, Val Loss: 41.0259
# Epoch [370/5000], Train Loss: 0.5526, Val Loss: 42.5812
# Epoch [380/5000], Train Loss: 0.6099, Val Loss: 41.6662
# Epoch [390/5000], Train Loss: 0.5135, Val Loss: 43.3136
# Epoch [400/5000], Train Loss: 0.6651, Val Loss: 43.3877
# Epoch [3820/5000], Train Loss: 0.3232, Val Loss: 43.6461
# Epoch [3830/5000], Train Loss: 0.3382, Val Loss: 43.2990
# Epoch [3840/5000], Train Loss: 0.3090, Val Loss: 42.5002
# Epoch [3850/5000], Train Loss: 0.3405, Val Loss: 43.7087
# Epoch [3860/5000], Train Loss: 0.3032, Val Loss: 43.2368
# Epoch [3870/5000], Train Loss: 0.9305, Val Loss: 43.9106
# Epoch [3880/5000], Train Loss: 0.2511, Val Loss: 42.5495
# Epoch [3890/5000], Train Loss: 0.3092, Val Loss: 41.3181
# Epoch [3900/5000], Train Loss: 0.6596, Val Loss: 41.8062
# Epoch [3910/5000], Train Loss: 0.1603, Val Loss: 41.8144
# Epoch [3920/5000], Train Loss: 0.2595, Val Loss: 41.7213
# Epoch [3930/5000], Train Loss: 0.2420, Val Loss: 41.3777
# Epoch [3940/5000], Train Loss: 0.2689, Val Loss: 40.4648
# Epoch [3950/5000], Train Loss: 0.2054, Val Loss: 42.2727
# Epoch [3960/5000], Train Loss: 0.1621, Val Loss: 41.0802
# Epoch [3970/5000], Train Loss: 0.1318, Val Loss: 42.0068
# Epoch [3980/5000], Train Loss: 0.1934, Val Loss: 41.5413
# Epoch [3990/5000], Train Loss: 0.1736, Val Loss: 41.6163
# Epoch [4000/5000], Train Loss: 0.2064, Val Loss: 40.9805
# Epoch [4010/5000], Train Loss: 2.2295, Val Loss: 42.5746
# Epoch [4020/5000], Train Loss: 0.5516, Val Loss: 40.1219
# Epoch [4030/5000], Train Loss: 0.3562, Val Loss: 41.5692
# Epoch [4040/5000], Train Loss: 0.2394, Val Loss: 41.3295
# Epoch [4050/5000], Train Loss: 0.2314, Val Loss: 41.1535
# Epoch [4060/5000], Train Loss: 0.1728, Val Loss: 40.2405
# Epoch [4070/5000], Train Loss: 0.2089, Val Loss: 41.0875
# Epoch [4080/5000], Train Loss: 0.2205, Val Loss: 39.9449
# Epoch [4090/5000], Train Loss: 0.7796, Val Loss: 39.9153
# Epoch [4100/5000], Train Loss: 0.1315, Val Loss: 40.6021
# Epoch [4110/5000], Train Loss: 0.2353, Val Loss: 40.1282
# Epoch [4120/5000], Train Loss: 0.2058, Val Loss: 39.3386
# Epoch [4130/5000], Train Loss: 0.3149, Val Loss: 40.7904
# Epoch [4140/5000], Train Loss: 0.2477, Val Loss: 40.0182
# Epoch [4150/5000], Train Loss: 0.2042, Val Loss: 39.2086
# Epoch [4160/5000], Train Loss: 0.1292, Val Loss: 40.0749
# Epoch [4170/5000], Train Loss: 0.2050, Val Loss: 39.1842
# Epoch [4180/5000], Train Loss: 0.1567, Val Loss: 39.9155
# Epoch [4190/5000], Train Loss: 0.1670, Val Loss: 39.7361
# Epoch [4200/5000], Train Loss: 0.1537, Val Loss: 39.2220
# Epoch [4210/5000], Train Loss: 0.1448, Val Loss: 39.7301
# Epoch [4220/5000], Train Loss: 0.1503, Val Loss: 39.5914
# Epoch [4230/5000], Train Loss: 0.1693, Val Loss: 39.6156
# Epoch [4660/5000], Train Loss: 0.1752, Val Loss: 39.6114
# Epoch [4670/5000], Train Loss: 0.0689, Val Loss: 39.3810
# Epoch [4680/5000], Train Loss: 0.2105, Val Loss: 39.2068
# Epoch [4690/5000], Train Loss: 0.4560, Val Loss: 39.6003
# Epoch [4700/5000], Train Loss: 0.1643, Val Loss: 38.8066
# Epoch [4710/5000], Train Loss: 0.1392, Val Loss: 38.8166
# Epoch [4720/5000], Train Loss: 0.1250, Val Loss: 38.6385
# Epoch [4730/5000], Train Loss: 0.1242, Val Loss: 38.5172
# Epoch [4740/5000], Train Loss: 0.0746, Val Loss: 39.0419
# Epoch [4750/5000], Train Loss: 0.1265, Val Loss: 39.1362
# Epoch [4760/5000], Train Loss: 0.7409, Val Loss: 40.3877
# Epoch [4770/5000], Train Loss: 0.1822, Val Loss: 39.6898
# Epoch [4780/5000], Train Loss: 0.0921, Val Loss: 39.3881
# Epoch [4790/5000], Train Loss: 0.1572, Val Loss: 39.6421
# Epoch [4800/5000], Train Loss: 0.1158, Val Loss: 39.7374
# Epoch [4810/5000], Train Loss: 0.0542, Val Loss: 39.4128
# Epoch [4820/5000], Train Loss: 0.1373, Val Loss: 38.8331
# Epoch [4830/5000], Train Loss: 0.1417, Val Loss: 39.6643
# Epoch [4840/5000], Train Loss: 0.2262, Val Loss: 39.2315
# Epoch [4850/5000], Train Loss: 0.2002, Val Loss: 38.8329
# Epoch [4860/5000], Train Loss: 0.3032, Val Loss: 39.9194
# Epoch [4870/5000], Train Loss: 0.0638, Val Loss: 39.1879
# Epoch [4880/5000], Train Loss: 0.1162, Val Loss: 39.1591
# Epoch [4890/5000], Train Loss: 0.1313, Val Loss: 39.0036
# Epoch [4900/5000], Train Loss: 0.0610, Val Loss: 39.4534
# Epoch [4910/5000], Train Loss: 0.2154, Val Loss: 38.7106
# Epoch [4920/5000], Train Loss: 0.0796, Val Loss: 39.2628
# Epoch [4930/5000], Train Loss: 0.1132, Val Loss: 39.5127
# Epoch [4940/5000], Train Loss: 0.0809, Val Loss: 39.7024
# Epoch [4950/5000], Train Loss: 0.1493, Val Loss: 39.9259
# Epoch [4960/5000], Train Loss: 0.1413, Val Loss: 39.8927
# Epoch [4970/5000], Train Loss: 0.1171, Val Loss: 40.2788
# Epoch [4980/5000], Train Loss: 0.2204, Val Loss: 39.4943
# Epoch [4990/5000], Train Loss: 0.0964, Val Loss: 39.8886
# Epoch [5000/5000], Train Loss: 0.8402, Val Loss: 39.4549

# %%
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title("Training vs Validation Loss")
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Set the model to evaluation mode
model.eval()

# Convert test data to PyTorch tensors
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1)

# Create test DataLoader
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Store predictions and true values
y_pred = []
y_true = []

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)
        outputs = model(X_batch)
        y_pred.extend(outputs.cpu().numpy())
        y_true.extend(y_batch.cpu().numpy())

# Flatten the list of predictions and true values
y_pred = np.array(y_pred).flatten()
y_true = np.array(y_true).flatten()

# Calculate MAE, MSE, and R-squared
mae = mean_absolute_error(y_true, y_pred)
mse = mean_squared_error(y_true, y_pred)
r2 = r2_score(y_true, y_pred)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Absolute Error (MAE): 4.508522033691406
# Mean Squared Error (MSE): 35.456398010253906
# R-squared: -0.29559528827667236
